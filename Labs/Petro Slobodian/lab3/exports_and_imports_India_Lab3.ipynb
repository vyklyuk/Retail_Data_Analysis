# %% [markdown]
# <center>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Exports and imports of India Analysis
#
# # Lab. 3. Data Analysis with Python
#
# Estimated time needed: **30** minutes
#
# ## About dataset and a course
#
# <details><summary>Click here for details about the dataset and the course.</summary>
#
# # Incoming data
# <ul>
#     <li>Country: This field represents the countries involved in the exports and imports.</li>
#     <li>Export: This field represents the total value of goods and services exported by India to other countries during a specific period. The value is measured in million US dollars.</li>
#     <li>Import: this field represents the total value of goods and services imported by India from other countries during a specific period. The value is measured in million US dollars.</li>
#     <li>Total Trade: This field represents the total value of exports and imports combined. It shows the volume of international trade that India has with other countries.</li>
#     <li>Trade Balance: This field represents the difference between the total value of exports and the total value of imports. A positive trade balance indicates that India is exporting more than it is importing, while a negative trade balance indicates the opposite.</li>
#     <li>Financial Year(start): This field represents the start date of the financial year during which the exports and imports were recorded.</li>
#     <li>Financial Year(end): This field represents the end date of the financial year during which the exports and imports were recorded.</li>
# </ul>
#
# # Target value
# <ul>
#     <li>Trade Balance</li>
# </ul>
#
# # Course objectives
# In this dataset, you will get data about exports and imports of India(1997-July 2022).</br>
# During this course you will be learning Data Analysis with Python. You will learn how to:
#     <li>Find average volume of export and import of India;</li>
#     <li>Analyze the structure of export-import operations by partner countries;</li>
#     <li>Examine the impact of the volume of exports and imports on the overall trade balance;</li>
#     <li>Estimate the planned volume and structure of imports and exports from India's partner countries for the next period,</li>
#
# using Python libraries.
# </details>
#
# ## Laboratory work objectives
#
# After completing this lab you will be able to:
#
# *   Explore features or charecteristics to predict total trade between countries

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
# <li><a href="https://#import_data">Import Data from Module</a></li>
# <li><a href="https://#pattern_visualization">Analyzing Individual Feature Patterns using Visualization</a></li>
# <li><a href="https://#discriptive_statistics">Descriptive Statistical Analysis</a></li>
# <li><a href="https://#data">Data</a></li>
# <li><a href="https://#correlation_causation">Correlation and Causation</a></li>
# <li><a href="https://#anova">ANOVA</a></li>
# </ol>
#
# </div>
#
# <hr>

# %% [markdown]
# <h2 id="import_data">1. Import Data from Module 2</h2>

# %% [markdown]
# <h4>Import libraries</h4>

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %% [markdown]
# <h2>Reading the dataset from the URL and adding the related headers</h2>

# %% [markdown]
# First, we assign the URL of the dataset to "path".

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0UUREN/clean_df.csv'

# %% [markdown]
# Use the Pandas method <b>read_csv()</b> to load the data from the web address.

# %%
df = pd.read_csv(path)

# %%
# To see what the data set looks like, we'll use the head() method.
df.head()

# %% [markdown]
# <h2 id="pattern_visualization">2. Analyzing Individual Feature Patterns Using Visualization</h2>

# %% [markdown]
# To install Seaborn we use pip, the Python package manager.

# %% [markdown]
# Import visualization packages "Matplotlib" and "Seaborn". Don't forget about "%matplotlib inline" to plot in a Jupyter notebook.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h4>How to choose the right visualization method?</h4>
# <p>When visualizing individual variables, it is important to first understand what type of variable you are dealing with. This will help us find the right visualization method for that variable.</p>

# %%
# list the data types for each column
print(df.dtypes)

# %% [markdown]
# As we can see, 'Financial Year (end)' has an 'object' type. That is because this column contains values 'till now'.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;">Question #1:</b>
#
# <b>What is the data type of the column "Trade Balance"? </b>
#
# </div>

# %%
# Write your code below and press Shift+Enter to execute
df['Trade Balance'].dtypes

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df['Trade Balance'].dtypes
# ```
#
# </details>

# %% [markdown]
# For example, we can calculate the correlation between variables  of type "int64" or "float64" using the method "corr":

# %%
df.corr()

# %% [markdown]
# The diagonal elements are always one; we will study correlation more precisely Pearson correlation in-depth at the end of the notebook.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;">Question #2:</b>
#
# <p>Find the correlation between the following columns: export, import, total trade, trade balance.</p>
# <p>Hint: if you would like to select those columns, use the following syntax: new_df[['Export','Import','Total Trade','Trade Balance']]</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute
df[['Export', 'Import', 'Total Trade', 'Trade Balance']].corr()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# new_df[['Export', 'Import', 'Total Trade', 'Trade Balance']].corr()
# ```
#
# </details>

# %% [markdown]
# <h2>Continuous Numerical Variables:</h2>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an export and total trade, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data.</p>

# %% [markdown]
# Let's see several examples of different linear relationships:

# %% [markdown]
# <h3>Positive Linear Relationship</h4>

# %% [markdown]
# Let's find the scatterplot of "Import" and "Total Trade".

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="Import", y="Total Trade", data=df)
plt.ylim(0, )

# %% [markdown]
# <p>As the size of import goes up, the Total Trade goes up: this indicates a positive direct correlation between these two variables. Import seems like a pretty good predictor of total trade since the regression line is almost a perfect diagonal line.</p>

# %% [markdown]
# We can examine the correlation between 'Import' and 'Total Trade' and see that it's approximately 0.94.

# %%
df[["Import", "Total Trade"]].corr()

# %% [markdown]
# Import is a potential predictor variable of Trade Balance. Let's find the scatterplot of "Import" and "Trade Balance".

# %%
sns.regplot(x="Import", y="Trade Balance", data=df)

# %% [markdown]
# <p>As import goes up, the trade balance goes down: this indicates an inverse/negative relationship between these two variables. Import could potentially be a predictor of trade balance.</p>

# %% [markdown]
# We can examine the correlation between 'Import' and 'Trade Balance' and see it's approximately -0.731.

# %%
df[['Import', 'Trade Balance']].corr()

# %% [markdown]
# <h3>Weak Linear Relationship</h3>

# %% [markdown]
# Let's see if "Export" is a predictor variable of "Trade Balance".

# %%
sns.regplot(x="Export", y="Trade Balance", data=df)

# %% [markdown]
# <p>Export does not seem like a good predictor of the Trade Balance at all since the regression line is close to horizontal. Also, the data points are very scattered and far from the fitted line, showing lots of variability. Therefore, it's not a reliable variable.</p>

# %% [markdown]
# We can examine the correlation between 'Export' and 'Trade Balance' and see it's approximately 0.021.

# %%
df[['Export', 'Trade Balance']].corr()

# %% [markdown]
#  <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;">Question #3 a):</b>
#
# <p>Find the correlation  between x="Total Trade" and y="Trade Balance".</p>
# <p>Hint: if you would like to select those columns, use the following syntax: df[["Total Trade","Trade Balance"]].  </p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #The correlation is 0.0823, the non-diagonal elements of the table.
#
# df[['Total Trade', 'Trade Balance']].corr()
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;">Question #3 b):</b>
#
# <p>Given the correlation results between "Total Trade" and "Trade Balance", do you expect a linear relationship?</p>
# <p>Verify your results using the function "regplot()".</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #There is a weak correlation between the variable 'stroke' and 'price.' as such regression will not work well. We can see this using "regplot" to demonstrate this.
#
# #Code:
# sns.regplot(x="Total Trade", y="Trade Balance", data=df)
#
# ```
#
# </details>

# %% [markdown]
# <h3>Categorical Variables</h3>
#
# <p>These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.</p>

# %% [markdown]
# Let's look at the relationship between "Total Trade" and "Country".

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.boxplot(x="Total Trade", y="Country", data=df[:1000],ax=ax)

# %% [markdown]
# We can easily see now biggest trading partners of India. Let's examine "Financial Year(end)" and "Total Trade":

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.boxplot(x="Financial Year(end)", y="Total Trade", data=df, ax=ax)
plt.ylim(0, 4000)

# %% [markdown]
# <p>Here we see that the distribution of total trade per each year.</p>

# %% [markdown]
# <h2 id="discriptive_statistics">3. Descriptive Statistical Analysis</h2>

# %% [markdown]
# <p>Let's first take a look at the variables by utilizing a description method.</p>
#
# <p>The <b>describe</b> function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.</p>
#
# This will show:
#
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %% [markdown]
# We can apply the method "describe" as follows:

# %%
df.describe()

# %% [markdown]
# The default setting of "describe" skips variables of type object. We can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include="object")

# %% [markdown]
# <h3>Value Counts</h3>

# %% [markdown]
# <p>Value counts is a good way of understanding how many units of each characteristic/variable we have. We can apply the "value_counts" method on the column "Trade Balance". Don’t forget the method "value_counts" only works on pandas series, not pandas dataframes. As a result, we only include one bracket <code>df['Trade Balance']</code>, not two brackets <code>df[['Trade Balance']]</code>.</p>

# %%
df['Trade Balance'].value_counts()

# %% [markdown]
# We can convert the series to a dataframe as follows:

# %%
df['Trade Balance'].value_counts().to_frame()

# %% [markdown]
# Let's repeat the above steps but save the results to the dataframe "trade_balance_counts" and rename the column  'Trade Balance' to 'value_counts'.

# %%
trade_balance_counts = df['Trade Balance'].value_counts().to_frame()
trade_balance_counts.rename(columns={'Trade Balance': 'value_counts'}, inplace=True)
trade_balance_counts

# %% [markdown]
# Now let's rename the index to 'Trade Balance':

# %%
trade_balance_counts.index.name = 'Trade Balance'
trade_balance_counts

# %% [markdown]
# We can repeat the above process for the variable 'Total Trade'.

# %%
# engine-location as variable
total_trade_counts = df['Total Trade'].value_counts().to_frame()
total_trade_counts.rename(columns={'Total Trade': 'value_counts'}, inplace=True)
total_trade_counts.index.name = 'Total Trade'
total_trade_counts.head(10)

# %% [markdown]
# <p>After examining the value counts of the Total Trade, we can see that engine location can be a good predictor variable for the trade balance.</p>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="Export", y="Import", data=df)
plt.ylim()

# %%
df[["Import", "Export"]].corr()

# %%
df['Import (normalized)'].value_counts().to_frame()

# %% [markdown]
# <h2 id='data'>4. Working with data</h2>

# %% [markdown]
# The goal of this laboratory work is to explore features or charecteristics to predict total trade between countries. As an example, we will take the biggest trading partner of India.

# %% [markdown]
# First of all, let's define the biggest trading partner of India.

# %%
total_trade_by_country = df.groupby('Country')['Total Trade'].sum()

# Find the country with the largest total trade
biggest_trading_partner = total_trade_by_country.idxmax()

# Print the result
print(f"The biggest trading partner is {biggest_trading_partner}")

# %% [markdown]
# <p>Now, when we know, that the biggest trading partner of India is USA, let's create a new DataFrame, that will contain only data, that is related to USA. We also have to drop unnecessary columns, such as:<br/>
# 'Financial Year(start)', 'Financial Year(end)', 'Country'</p>

# %%
new_df = df[df['Country'] == biggest_trading_partner]

# As index, we set concatenation of 'Financial Year(start)' and 'Financial Year(end)'
new_df.index = [f"{start}-{end}" for start, end in zip(new_df['Financial Year(start)'], new_df['Financial Year(end)'])]

# Drop unnecessary columns
new_df=new_df.drop(['Financial Year(start)', 'Financial Year(end)', 'Country'], axis=1)

new_df.index.name = 'Financial Year'
new_df

# %% [markdown]
# Let's use a seaborn plot to visualize the amount of total trade between India and USA since 2010.

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(15, 6))
sns.lineplot(data=new_df[13:], x=new_df.index[13:], y="Total Trade")
plt.title("Total Trade Over Time")
plt.xlabel("Financial Year")
plt.ylabel("Total Trade (in billions USD)")
plt.show()

# %% [markdown]
# <p>Visualization is very important in data science, and Python visualization packages provide great freedom. We will go more in-depth in a separate Python visualizations course.</p>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
#  <b style="font-size: 2em; font-weight: bold;">Attention!</b>
#
# <p>Since now, we will use <code>new_df</code> as our main dataframe.</p>
# </div>

# %% [markdown]
# <h2 id="correlation_causation">5. Correlation and Causation</h2>

# %% [markdown]
# <p><b>Correlation</b>: a measure of the extent of interdependence between variables.</p>
#
# <p><b>Causation</b>: the relationship between cause and effect between two variables.</p>
#
# <p>It is important to know the difference between these two. Correlation does not imply causation. Determining correlation is much simpler  the determining causation as causation may require independent experimentation.</p>

# %% [markdown]
# <p><b>Pearson Correlation</b></p>
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li><b>1</b>: Perfect positive linear correlation.</li>
#     <li><b>0</b>: No linear correlation, the two variables most likely do not affect each other.</li>
#     <li><b>-1</b>: Perfect negative linear correlation.</li>
# </ul>

# %% [markdown]
# <p>Pearson Correlation is the default method of the function "corr". Like before, we can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>

# %%
new_df.corr()

# %% [markdown]
# Sometimes we would like to know the significant of the correlation estimate.

# %% [markdown]
# <b>P-value</b>
#
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
#
# <ul>
#     <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %% [markdown]
# We can obtain this information using  "stats" module in the "scipy"  library.

# %%
from scipy import stats

# %% [markdown]
# <h3>Export vs. Trade Balance</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Export' and 'Trade Balance'.

# %%
pearson_coef, p_value = stats.pearsonr(new_df['Export'], new_df['Trade Balance'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between export and trade balance is statistically significant, and the linear relationship is extremely strong  (~0.913).</p>

# %% [markdown]
# <h3>Import vs. Trade Balance</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Import' and 'Trade Balance'.

# %%
pearson_coef, p_value = stats.pearsonr(new_df['Import'], new_df['Trade Balance'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between import and trade balance is statistically significant, and the linear relationship is extremely strong (~0.756).</p>

# %% [markdown]
# <h3>Total Trade vs. Trade Balance</h3>

# %%
pearson_coef, p_value = stats.pearsonr(new_df['Total Trade'], new_df['Trade Balance'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)

# %% [markdown]
# <h4>Conclusion:</h4>
#
# Since the p-value is < 0.001, the correlation between total trade and trade balance is statistically significant, and  and the linear relationship is extremely strong (~0.862).

# %% [markdown]
# <h2 id="anova">6. ANOVA</h2>

# %% [markdown]
# <h3>ANOVA: Analysis of Variance</h3>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant our calculated score value is.</p>
#
# <p>If our price variable is strongly correlated with the variable we are analyzing, we expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %%
from scipy.stats import f_oneway

anova_df = new_df[['Export', 'Import', 'Total Trade', 'Trade Balance']]

sns.boxplot(data=anova_df)
plt.show()

f_stat, p_val = f_oneway(new_df['Export'], new_df['Import'], new_df['Total Trade'], new_df['Trade Balance'])

print("F-Statistic: {:.2f}".format(f_stat))
print("P-value: {:.2f}".format(p_val))
if p_val < 0.05:
    print('There is a statistically significant difference between the means of the groups.')
else:
    print('There is no statistically significant difference between the means of the groups.')

# %%
export_low = df['Export_Low']
export_medium = df['Export_Medium']
export_high = df['Export_High']

f_statistic, p_value = stats.f_oneway(export_low, export_medium, export_high)
print("F-Statistic: {:.2f}".format(f_statistic))
print("P-value: {:.2f}".format(p_value))

# %% [markdown]
# <h3>Conclusion: Important Variables</h3>

# %% [markdown]
# <p>We now have a better idea of what our data looks like and which variables are important to take into account when predicting the Total Trade. We have narrowed it down to the following variables:</p>
#
# Continuous numerical variables:
#
# <ul>
#     <li>Export</li>
#     <li>Import</li>
#     <li>Trade Balance</li>
# </ul>
#
#
# <p>As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.</p>

# %% [markdown]
# <h2 id="anova">7. Save data</h2>

# %% [markdown]
# Finally, let's save our new data set, only with columns, that are important for prediction.

# %%
new_df.drop(['Total Trade (in rupees)', 'Trade Balance (in rupees)',
       'Import (normalized)', 'Export (normalized)',
       'Total Trade (normalized)', 'Export_Low', 'Export_Medium',
       'Export_High'], axis=1, inplace=True)

new_df.to_csv('new_df.csv')

# %% [markdown]
# ### Thank you for completing this lab!
#
# ## Authors
#
# <a href='https://author.skills.network/instructors/yaroslav_vyklyuk_2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0UUREN2974-2023-01-01'> Yaroslav Vyklyuk</a>
#
# <a href='https://author.skills.network/instructors/olga_kavun?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0UUREN2974-2023-01-01'>Olga Kavun</a>
#
# <a href='https://author.skills.network/instructors/petro_slobodian?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0UUREN2974-2023-01-01'>Petro Slobodian</a>
#
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                            |
# | ----------------- | ------- | ---------- | --------------------------------------------- |
# | 2023-04-13        | 1.0     | Slobodian    | Created Laboratory work                            |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2023. All rights reserved. <h3/>
