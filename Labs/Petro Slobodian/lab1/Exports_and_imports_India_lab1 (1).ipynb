# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Exports and Imports of India(1997-July 2022)
# # Lab. 1. Dataset investigation
# Estimated time needed: **10** minutes
# # Course objectives
# In this dataset, you will get data about exports and imports of India(1997-July 2022).</br>
# During this course you will be learning Data Analysis with Python. You will learn how to:
#     <li>Find average volume of export and import of India;</li>
#     <li>Analyze the structure of export-import operations by partner countries;</li>
#     <li>Examine the impact of the volume of exports and imports on the overall trade balance;</li>
#     <li>Estimate the planned volume and structure of imports and exports from India's partner countries for the next period,</li>
#
# using Python libraries.
# <hr>
#
# # Incoming data
# <ul>
#     <li>Country: This field represents the countries involved in the exports and imports.</li>
#     <li>Export: This field represents the total value of goods and services exported by India to other countries during a specific period. The value is measured in million US dollars.</li>
#     <li>Import: this field represents the total value of goods and services imported by India from other countries during a specific period. The value is measured in million US dollars.</li>
#     <li>Total Trade: This field represents the total value of exports and imports combined. It shows the volume of international trade that India has with other countries.</li>
#     <li>Trade Balance: This field represents the difference between the total value of exports and the total value of imports. A positive trade balance indicates that India is exporting more than it is importing, while a negative trade balance indicates the opposite.</li>
#     <li>Financial Year(start): This field represents the start date of the financial year during which the exports and imports were recorded.</li>
#     <li>Financial Year(end): This field represents the end date of the financial year during which the exports and imports were recorded.</li>
# </ul>
#
# ## Laboratory work objectives
#
# After completing this lab. you will be able to:
# *   Learn how to read, modify and save data using Python
# *   Acquire data in various ways
# *   Obtain insights from data with Pandas library
# *   Learn how to explore data, creating cross tables
#
# # License
# The statistical data was obtained from the https://www.kaggle.com/datasets/ramjasmaurya/exports-and-imports-of-india19972022. This DataSet released under CC0: Public Domain license that allow of copy, modify, distribute and perform the work, even for commercial purposes, all without asking permission.
#
# <ul><li><a href="https://creativecommons.org/publicdomain/zero/1.0/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0Q5HEN2621-2023-01-01">CC0: Public Domain</a></li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
#     <li><a href="https://#data_acquisition">Data Acquisition</a>
#     <li><a href="https://#basic_insight">Basic Insight of Dataset</a></li>
# </ol>
#
# </div>
# <hr>

# %% [markdown]
# <h1 id="data_acquisition">Data Acquisition</h1>
# <p>
# There are various formats for a dataset: .csv, .json, .xlsx  etc. The dataset can be stored in different places, on your local machine or sometimes online.<br>
#
# In this section, you will learn how to load a dataset into our Jupyter Notebook.<br>
#
# In our case, the Dataset of Exports and Imports of India(1997-July 2022) is an online source, and it is in a CSV (comma separated value) format. Let's use this dataset as an example to practice data reading.
#
# <ul>
#     <li>Data source: <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0Q5HEN/India_trades.csv" target="_blank">
#         https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0Q5HEN/India_trades.csv</a></li>
#     <li>Data type: csv</li>
# </ul>
# The Pandas Library is a useful tool that enables us to read various datasets into a dataframe; our Jupyter notebook platforms have a built-in <b>Pandas Library</b> so that all we need to do is import Pandas without installing.
# </p>

# %% [markdown]
# If you run the lab locally using Anaconda, you can load the correct library and versions by uncommenting the following:

# %%
#install specific version of libraries used in  lab
#! mamba install pandas==1.3.3  -y
#! mamba install numpy=1.21.2 -y

# %%
# import pandas library
import pandas as pd

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We use <code>pandas.read_csv()</code> function to read the csv file. In the brackets, we put the file path along with a quotation mark so that pandas will read the file into a dataframe from that address. The file path can be either an URL or your local file address.<br>
#
# You can also assign the dataset to any variable you create.
#
# </p>

# %%
path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0Q5HEN/India_trades.csv"

# %%
# Read the online file by the URL provides above, and assign it to variable "df"

df = pd.read_csv(path)

# %% [markdown]
# After reading the dataset, we can use the <code>dataframe.head(n)</code> method to check the top n rows of the dataframe, where n is an integer. Contrary to <code>dataframe.head(n)</code>, <code>dataframe.tail(n)</code> will show you the bottom n rows of the dataframe.

# %%
# show the first 5 rows using dataframe.head() method
print("The first 5 rows of the dataframe") 
df.head(5)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question #1: </h1>
# <b>Check the bottom 10 rows of data frame "df".</b>
# </div>

# %%
# Write your code below and press Shift+Enter to execute:

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# print("The last 10 rows of the dataframe\n")
# df.tail(10)
# ```

# %% [markdown]
# <h1 id="headers">Headers</h1>
# <p>
# Take a look at our dataset.
# To better describe our data, we can introduce a header.
# </p>

# %%
headers = list(df.columns.values)

# Print the headers
print(headers)

# %% [markdown]
# <p>As we can see, our dataset has the next headers:
#     <ul>
#         <li><code>Country</code></li>
#         <li><code>Export</code></li>
#         <li><code>Import</code></li>
#         <li><code>Total Trade</code></li>
#         <li><code>Trade Balance</code></li>
#         <li><code>Financial Year(start)</code></li>
#         <li><code>Financial Year(end)</code></li>
#     </ul>
# <p>Pandas library allows you to change the headers of the dataset, using <code>rename()</code> function.</p>
# <p>Here's an example: </p>

# %%
new_headers = ['countries', 'India_export', 'India_import', 'Total_trade', 'Balance_of_trade', 'Start_of_financial_year', 'End_of_financial_year']

# Use the rename() function to change the headers
df = df.rename(columns=dict(zip(df.columns, new_headers)))

# Print the new headers
df.head()

# %% [markdown]
# <p>As we can see, headers have changed into new ones. </p>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question #2: </h1>
#
# <p>
# Rename the headers, using previous values: </p>
# <p>
# <code>['Country', 'Export', 'Import', 'Total Trade', 'Trade Balance', 'Financial Year(start)', 'Financial Year(end)']</code>
# </p>
#
# Apply the  method to ".rename()".
#
# <b>ATTENTION!</b></br>
# To complete the laboratory work successfully, don't miss this task.
# </div>

# %%
# Write your code below and press Shift+Enter to execute:

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# new_headers = ['Country', 'Export', 'Import', 'Total Trade', 'Trade Balance', 'Financial Year(start)', 'Financial Year(end)']
#
# df = df.rename(columns=dict(zip(df.columns, new_headers)))
#
# df.head()
# ```
#
# </details>

# %% [markdown]
# <h1 id="basic_insight">Basic Insight of Dataset</h1>
# <p>
# After reading data into Pandas dataframe, it is time for us to explore the dataset.<br>
#
# There are several ways to obtain essential insights of the data to help us better understand our dataset.
#
# </p>

# %% [markdown]
# <h2>Data Types</h2>
# <p>
# Data has a variety of types.<br>
#
# The main types stored in Pandas dataframes are <b>object</b>, <b>float</b>, <b>int</b>, <b>bool</b> and <b>datetime64</b>. In order to better learn about each attribute, it is always good for us to know the data type of each column. In Pandas:
#
# </p>

# %% [markdown]
# A series with the data type of each column is returned.

# %%
# check the data type of data frame "df" by .dtypes
print(df.dtypes)

# %% [markdown]
# <p>
# As shown above, it is clear to see that the data type of "Country", "Export", "Import", "Total Trade", "Trade Balance" and "Financial Year(end)" are <code>object</code>,
# and "Financial Year(Start)" is <code>int64</code>.
# </p>
# <p>
# These data types can be changed; we will learn how to accomplish this in a later module.
# </p>

# %% [markdown]
# <h2>Describe</h2>
# If we would like to get a statistical summary of each column e.g. count, column mean value, column standard deviation, etc., we use the describe method:

# %% [markdown]
# <code>dataframe.describe()</code>

# %%
df.describe()

# %% [markdown]
# <p>
# This shows the statistical summary of all numeric-typed (int, float) columns.<br>
#
# For example, the attribute "Financial Year(start)" has 5994 counts, the mean value of this column is 2009.596, the standard deviation is 7.46, the minimum value is 1997, 25th percentile is 2003, 50th percentile is 2010, 75th percentile is 2016, and the maximum value is 2022. <br>
#
# However, what if we would also like to check all the columns including those that are of type object? <br><br>
#
# You can add an argument <code>include = "all"</code> inside the bracket. Let's try it again.
#
# </p>

# %%
# describe all the columns in "df" 
df.describe(include = "all")

# %% [markdown]
# <p>
# Now it provides the statistical summary of all the columns, including object-typed attributes.<br>
#
# We can now see how many unique values there, which one is the top value and the frequency of top value in the object-typed columns.<br>
#
# Some values in the table above show as "NaN". This is because those numbers are not available regarding a particular column type.<br>
#
# </p>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question #3: </h1>
#
# <p>
# You can select the columns of a dataframe by indicating the name of each column. For example, you can select the three columns as follows:
# </p>
# <p>
#     <code>dataframe[[' column 1 ',column 2', 'column 3']]</code>
# </p>
# <p>
# Where "column" is the name of the column, you can apply the method  ".describe()" to get the statistics of those columns as follows:
# </p>
# <p>
#     <code>dataframe[[' column 1 ',column 2', 'column 3'] ].describe()</code>
# </p>
#
# Apply the  method to ".describe()" to the columns 'Financial Year(start)' and 'Financial Year(end)'.
#
# </div>

# %%
# Write your code below and press Shift+Enter to execute:

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[['Financial Year(start)', 'Financial Year(end)']].describe(include="all")
# ```
#
# </details>

# %% [markdown]
# <h2>Info</h2>
# Another method you can use to check your dataset is:

# %% [markdown]
# <code>dataframe.info()</code>

# %% [markdown]
# It provides a concise summary of your DataFrame.
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
# look at the info of "df":
df.info()

# %% [markdown]
# <h2>Save Dataset</h2>
# <p>
# Correspondingly, Pandas enables us to save the dataset to csv. By using the <code>dataframe.to_csv()</code> method, you can add the file path and name along with quotation marks in the brackets.
# </p>
# <p>
# For example, if you would save the dataframe <b>df</b> as <b>India_trades.csv</b> to your local machine, you may use the syntax below, where <code>index = False</code> means the row names will not be written.
# </p>

# %%
df.to_csv("India_trades.csv", index=False)

# %% [markdown]
# We can also read and save other file formats. We can use similar functions like **`pd.read_csv()`** and **`df.to_csv()`** for other data formats. The functions are listed in the following table:

# %% [markdown]
# <h2>Read/Save Other Data Formats</h2>
#
# | Data Formate |        Read       |            Save |
# | ------------ | :---------------: | --------------: |
# | csv          |  `pd.read_csv()`  |   `df.to_csv()` |
# | json         |  `pd.read_json()` |  `df.to_json()` |
# | excel        | `pd.read_excel()` | `df.to_excel()` |
# | hdf          |  `pd.read_hdf()`  |   `df.to_hdf()` |
# | sql          |  `pd.read_sql()`  |   `df.to_sql()` |
# | ...          |        ...        |             ... |

# %% [markdown]
# <h1>Excellent! You have just completed the  Introduction Notebook!</h1>

# %% [markdown]
# ### Thank you for completing this lab!
#
# ## Authors
#
# <a href='https://author.skills.network/instructors/yaroslav_vyklyuk_2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0Q5HEN2621-2023-01-01'> Yaroslav Vyklyuk</a>
#
# <a href='https://author.skills.network/instructors/olga_kavun?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0Q5HEN2621-2023-01-01'>Olga Kavun</a>
#
# <a href='https://author.skills.network/instructors/petro_slobodian?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0Q5HEN2621-2023-01-01'>Petro Slobodian</a>
#
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                            |
# | ----------------- | ------- | ---------- | --------------------------------------------- |
# | 2023-03-17        | 1.0     | Slobodian    | Created Laboratory work                            |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2023. All rights reserved. <h3/>
