# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Motorcycle sales analysis
#
# # *Lab 6. Predicting total cost of purchase depend on type of motorcycle product*
# Estimated time needed: **1 hour**
#
#
# ## Objectives
# After completing this lab you will be able to:
#
# *   Be confident about your data analysis skills

# %% [markdown]
# <details><summary><b style="font-size: 1.5em; font-weight: bold;">Click here to see content, description of dataset, source of dataset and licence</b></summary>
# <br/>
#     <b style="font-size: 1.2em; font-weight: bold;">Content</b>
# <p>You work in the accounting department of a company that sells motorcycle parts. The company operates three warehouses in a large metropolitan area.</p>
#
#
# <b style="font-size: 1.2em; font-weight: bold;">Dataset Glossary (Column-wise)</b>
# <ul>
#     <li>Date<p>Determines the date when client bought products</p></li>
#     <li>Warehouse<p>The warehouse location.</p></li>
#     <li>Client type<p>Determines how client bought the products. This column can be only Retail or Wholesale</p></li>
#     <li>Product line<p>Name of product (part of motorcycle)</p></li>
#     <li>Quantity<p>The count bought product</p></li>
#     <li>Unit price<p>Cost of one product</p></li>
#     <li>Total<p>The total purchase price</p></li>
#     <li>Payment<p>Determines the method of payment for the purchase. This dataset has three types of payment: Credit card, cash or transfer</p></li>
# </ul>
#
# <b style="font-size: 1.2em; font-weight: bold;">Target field</b>
# <ul>
#     <li>Total</li>
# </ul>
#
# <b style="font-size: 1.2em; font-weight: bold;">Data source and licence</b>
#     <p>The Motorcycle sales analysis Dataset is an online source, and it is in a CSV (comma separated value) format. Let's use this dataset as an example to practice data reading.</p>
#
# <ul>
#     <li>Data source: <a href="https://www.kaggle.com/datasets/devijeganath/motorcycle-sales-analysis?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0YF2EN3192-2023-01-01">https://www.kaggle.com/datasets/devijeganath/motorcycle-sales-analysis</a></li>
#     <li>Data type: csv</li>
#     <li>Licence: <a href="https://creativecommons.org/publicdomain/zero/1.0/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0YF2EN3192-2023-01-01">CC0: Public Domain</a></li>
# </ul>
# <p>
# This DataSet released under CC0: Public Domain license that allow of copy, modify, distribute and perform the work, even for commercial purposes, all without asking permission.
# The person who associated a work with this deed has dedicated the work to the public domain by waiving all of his or her rights to the work worldwide under copyright law, including all related and neighboring rights, to the extent allowed by law.
# </p>
# You can copy, modify, distribute and perform the work, even for commercial purposes, all without asking permission.
# </details>

# %% [markdown]
# <b style="font-size: 1.5em; font-weight: bold;">Table of Contents</b>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ul>
#     <li><a href="#id1">Question #1. Data types</a></li>
#     <li><a href="#id2">Question #2. Transforming all data and correlation</a></li>
#     <li><a href="#id3">Question #3. Dropping unnecessary fields</a></li>
#     <li><a href="#id4">Question #4. Data grouping</a></li>
#     <li><a href="#id5">Question #5. Regplot</a></li>
#     <li><a href="#id6">Question #6. Boxplot</a></li>
#     <li><a href="#id7">Question #7. Transforming some data</a></li>
#     <li><a href="#id8">Question #8. Simple linear regression</a></li>
#     <li><a href="#id9">Question #9. Multiple linear regression</a></li>
#     <li><a href="#id10">Question #10. Polynomial regression</a></li>
#     <li><a href="#id11">Question #11. Multiple polynomial regression. Pipeline</a></li>
#     <li><a href="#id12">Question #12. Ridge regression</a></li>
# </ul>
# </div>
#
# <hr>

# %%
! mamba install scikit-learn -y

# %% [markdown]
# You will need the following libraries:

# %% [markdown]
# <b style="font-size: 1.2em; font-weight: bold;">Run the code below twice</b><br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import OrdinalEncoder, PolynomialFeatures, StandardScaler 
from sklearn.linear_model import LinearRegression, Ridge
import seaborn as sns 
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, train_test_split, cross_val_predict, GridSearchCV
from sklearn import set_config
set_config(display="diagram")

# %% [markdown]
# Load the Data

# %% [markdown]
# This dataset was hosted on IBM Cloud object. Click <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0YF2EN/motorcycles.csv">HERE</a> for free storage.

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0YF2EN/motorcycles.csv'

# %%
df= pd.read_csv(path)

# %% [markdown]
# We use the method  <code>head()</code>  to display the first 5 columns of the dataframe:

# %%
df.head()

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"><a name="id1" style="text-decoration: none;"><font color="red">Question #1: Data types</font></a></b><br>
# <b style="font-size: 1.2em">Print the data type for each field (<code>.dtypes</code>). For all 'object' fields change type to 'category'(<code>.astype()</code>).</b>
#
# </div>

# %%
#Print data types
df.dtypes

# %%
#Correct data types and check them with dtypes
columns = df.columns[df.dtypes == 'object']
df[columns] = df[columns].astype('category')
df.dtypes

# %% [markdown]
# You must have get such result<br>
# <li>Date            <b style="font-weight:bold">category</b></li>
# <li>Warehouse       <b style="font-weight:bold">category</b></li>
# <li>Client type     <b style="font-weight:bold">category</b></li>
# <li>Product line    <b style="font-weight:bold">category</b></li>
# <li>Quantity        <b style="font-weight:bold">int64</b></li>
# <li>Unit price      <b style="font-weight:bold">float64</b></li>
# <li>Total           <b style="font-weight:bold">float64</b></li>
# <li>Payment         <b style="font-weight:bold">category</b></li>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id2" style="text-decoration: none;" ><font color="red">Question #2: Transforming all data and correlation</font></a></b><br>
# <li><b style="font-size: 1.2em">Make copy of your dataset (<code>.copy()</code>)</b></li>
# <li><b style="font-size: 1.2em">For created copy use method <code>.fit_transform()</code> from class <code>OrdinalEncoder()</code> to transform all your data into number values</b></li>
# <li><b style="font-size: 1.2em">Find correlation between all fields (<code>.corr()</code>). Pay attention the coefficient of correlation between target field Total and the rest fields</b></li>
# <b style="font-size: 1.2em; font-weight:bold">All actions above do with COPY, not original dataset </b>
# </div>

# %%
#Make copy your dataset.
data = df.copy()

# %%
#Transform your data and find coefficient of correlation
enc = OrdinalEncoder()
data[data.columns] = enc.fit_transform(data[data.columns])
data.corr()

# %% [markdown]
# You see that correlation between field Date and Total is ~-0.003, correlation between Warehouse and Total is ~-0.009, so we can delete them from dataset because they haven't affect on target field Total

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id3" style="text-decoration: none;"><font color="red">Question #3: Dropping unnecessary fields</font></a></b><br>
# <b style="font-size: 1.2em">From table you see that fields Date and Warehouse hasn't high link with target field Total. So we can delete them. Also we need to delete field Unit price, because it is obtained by dividing Total field by Quantity.</b><br>
# <b style="font-size: 1.2em;">Drop columns Date, Warehouse and Unit price (<code>.drop()</code>). Don't delete other fields</b>
#
# </div>

# %%
#Drop unnecessary fields
df.drop(['Date','Warehouse','Unit price'],axis = 1,inplace = True)
df

# %% [markdown]
# After completing this question you will have dataset with such fields:<br>
# <li>Client type</li>
# <li>Product line</li>
# <li>Quantity</li>
# <li>Total</li>
# <li>Payment</li>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id4" style="text-decoration: none;"><font color="red">Question #4: Data grouping</font></a></b><br>
# <b style="font-size: 1.2em">Group your data by products and find total turnover for each product<code>.groupby()</code></b>
#
# </div>

# %%
#Group your data
df.groupby('Product line')['Total'].sum().to_frame()

# %% [markdown]
# The result must be follow:<br>
# <li><b style="font-weight:bold">Breaking system</b>  38350.15</li>
# <li><b style="font-weight:bold">Electrical system</b> 43612.71</li>
# <li><b style="font-weight:bold">Engine</b> 37945.38</li>
# <li><b style="font-weight:bold">Frame & body</b> 69024.73</li>
# <li><b style="font-weight:bold">Miscellaneous</b> 27165.82</li>
# <li><b style="font-weight:bold">Suspension & traction</b> 73014.21</li>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id5" style="text-decoration: none;"><font color="red">Question #5: Regplot</font></a></b><br>
# <p style="font-size: 1.2em">Field Product line has six unique products. To find them use <code>.unique()</code></p>
# <b style="font-size: 1.2em">Use function regplot to build relationship between quantity of bought products each type and target field Total. Also find coefficient of correlation between quantity of bought products each type and Total. Make conclusion whether type of product has affect on target field Total </b>
#
# </div>

# %%
#Build regplot
width = 12
height = 12
plt.figure(figsize = (width, height))
for name in df['Product line'].unique():
    sns.regplot(x = 'Quantity', y = 'Total', data = df.loc[df['Product line'] == name], label = name)
plt.legend()

# %%
#Find coefficient of correlation
for name in df['Product line'].unique():
    print(name,'\n',df.loc[df['Product line'] == name,['Quantity','Total']].corr(),'\n')

# %% [markdown]
# From coefficient of correlation you see that for each product type relationship between fields Quantity and Total is very strong (more than 0.9), so quantity bought product of any type has the same affect on target field Total

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id6" style="text-decoration: none;"><font color="red">Question #6: Boxplot</font></a></b><br>
# <b style="font-size: 1.2em">Use function boxplot to find out whether type of Payment for special product type has affect on Total turnover. Build this graphic for <b style="font-weight: bold">Engine</b> and <b style="font-weight: bold">Breaking system</b>.</b>
#
# </div>

# %%
#Boxplot for Engine
sns.boxplot(x ='Payment', y = 'Total', data = df.loc[df['Product line'] == 'Engine'])
plt.title('Engine')

# %%
#Boxplot for Breaking system
sns.boxplot(x = 'Payment', y = 'Total', data = df.loc[df['Product line'] == 'Breaking system'])
plt.title('Breaking system')

# %% [markdown]
# You see that payment type for product <b style="font-weight:bold">Engine</b> has a little more affect on Total than payment type for product <b style="font-weight:bold">Breaking system</b>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id7" style="text-decoration: none;"><font color="red">Question #7: Transforming some data</font></a></b><br>
# <b style="font-size: 1.2em">For your original dataset use <code>fit_transform()</code> from <code>OrdinalEncoder</code> to transform ONLY FIELDS 'Client type' and 'Payment'. Create copy dataset is not necessary</b>
#
# </div>

# %%
#Transform fields
df[['Client type','Payment']] = enc.fit_transform(df[['Client type','Payment']])

# %% [markdown]
# The values in field Client type can be only 0 or 1, because there are two unique values in this column, and values in field Payment can be only 0, 1 or 2, because there are three unique payment methods in this column

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id8" style="text-decoration: none;"><font color="red">Question #8: Simple Linear Regression</font></a></b><br>
# <p style="font-size: 1.2em">Starting from this question you will split your data into test set and train set.</p>
# <li><b style="font-size: 1.2em">Split your data for product <b style="font-weight: bold">Miscellaneous</b> into test and train data. Use 10% test data. Set the parameter <code>shuffle = False</code>. (Use method <code>(train_test_split())</code></b></li>
# <li><b style="font-size: 1.2em">Create LinearRegression model. Fit it using train data and one feature Quantity. Find the values of intercept and slope.</b></li>
# <li><b style="font-size: 1.2em">Calculate the $R^{2}$ <code>(.score())</code> for train and test data</b></li>
# <li><b style="font-size: 1.2em">Predict data using test set. Build graphic with predicted test data and real test data</b></li>
# </div>

# %%
#Split data, create regression model and fit it
x_data = df.loc[df['Product line'] == 'Miscellaneous',['Quantity']]
y_data = df.loc[df['Product line'] == 'Miscellaneous',['Total']]
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.1, shuffle = False)
lm = LinearRegression()
lm.fit(x_train, y_train)

# %%
#Find intercept and slope
print('Intercept = ',lm.intercept_)
print('Slope = ',lm.coef_)

# %% [markdown]
# The expected values:<br>
# Intercept = ~ -6.2<br>
# Slope = ~ 23.7

# %%
#Calculate R^2 score for test and train data. Make conclusion is there underfitting or overfitting or model is trained very well
print('R^2 for train data {:.2f}'.format(lm.score(x_train, y_train)))
print('R^2 for test data {:.2f}'.format(lm.score(x_test, y_test)))

# %% [markdown]
# The expected values of  $R^{2}$:<br>
# For train data ~ 0.93<br>
# For test data ~ 0.98

# %%
#Predict values and build graphic
yhat = lm.predict(x_test)
plt.title('Prediction for product Miscellaneous')
plt.xlabel('Index')
plt.ylabel('Total cost')
plt.plot(y_test.index, y_test, label = 'Actual test data')
plt.plot(y_test.index, yhat, label = 'Predicted test data')
plt.legend()

# %% [markdown]
# So, analyzing the  $R^{2}$ score for train and test data and graphic with real test data and predicted test data we can make conclusion that our model is trained very well ($R^{2}$ for test and train data is more than 0.9)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id9" style="text-decoration: none;"><font color="red">Question #9: Multiple Linear Regression</font></a></b><br>
# <li><b style="font-size: 1.2em">Split your data for product <b style="font-weight: bold">Electrical system</b> into test and train data. Use 10% test data. Set the parameter <code>shuffle = False</code>. (Use method <code>(train_test_split())</code></b></li>
# <li><b style="font-size: 1.2em">Create LinearRegression model. Fit it using train data and features Client type, Quantity and Payment. Find the values of intercept and slope.</b></li>
# <li><b style="font-size: 1.2em">Calculate the $R^{2}$ <code>(.score())</code> for train and test data</b></li>
# <li><b style="font-size: 1.2em">Predict data using test set. Build graphic with predicted test data and real test data</b></li>
#
# </div>

# %%
#Split data, create regression model and fit it
x_data = df.loc[df['Product line'] == 'Electrical system',['Quantity','Client type','Payment']]
y_data = df.loc[df['Product line'] == 'Electrical system',['Total']]
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.1, shuffle = False)
lm = LinearRegression()
lm.fit(x_train, y_train)

# %%
#Find intercept and slope
print('Intercept = ',lm.intercept_)
print('Slope = ',lm.coef_)

# %% [markdown]
# The expected values:<br>
# Intercept = ~ -7.97<br>
# Slope = ~ [25.81  5.23  5.47]

# %%
#Calculate R^2 score for test and train data. Make conclusion is there underfitting or overfitting or model is trained very well
print('R^2 for train data {:.2f}'.format(lm.score(x_train, y_train)))
print('R^2 for test data {:.2f}'.format(lm.score(x_test, y_test)))

# %% [markdown]
# The expected values of R^2:<br>
# For train data ~ 0.96 <br>
# For test data ~ 0.93

# %%
#Predict values and build graphic
yhat = lm.predict(x_test)
plt.title('Prediction for product Electrical system')
plt.xlabel('Index')
plt.ylabel('Total cost')
plt.plot(y_test.index, y_test, label = 'Actual test data')
plt.plot(y_test.index, yhat, label = 'Predicted test data')
plt.legend()

# %% [markdown]
# So, analyzing the  $R^{2}$ score for train and test data and graphic with real test data and predicted test data we can make conclusion that our model is trained very well ($R^{2}$ for test and train data is more than 0.9)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id10" style="text-decoration: none;"><font color="red">Question #10: Polynomial Regression</font></a></b><br>
# <li><b style="font-size: 1.2em">Split your data for product <b style="font-weight: bold">Frame & body</b> into test and train data. Use 10% test data. Set the parameter <code>shuffle = False</code>. (Use method <code>(train_test_split())</code></b></li>
# <li><b style="font-size: 1.2em">Create PolynomialFeatures of degree 4. Perform a polynomial transformation on the feature Quantity only for arrays x_train and x_test <code>(PolynomialModel.fit_transform())</code>.</b></li>
# <li><b style="font-size: 1.2em">Create LinearRegression model and train it using transformed array x_train and not transformed y_train</b></li>
# <li><b style="font-size: 1.2em">Calculate the $R^{2}$ for created Linear model <code>(.score())</code> for train and test data</b></li>
# <li><b style="font-size: 1.2em">Predict data using test set. Build graphic with predicted test data and real test data</b></li>
#
# </div>

# %%
#Split data and transform arrays x_train and x_test
x_data = df.loc[df['Product line'] == 'Frame & body',['Quantity']]
y_data = df.loc[df['Product line'] == 'Frame & body',['Total']]
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.1, shuffle = False)
poly = PolynomialFeatures(degree = 4)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)

# %%
#Create linear model and fit it. Calculate the R^2 for train and test data. Make conclusion is there underfitting or overfitting or model is trained very well
polynom = LinearRegression()
polynom.fit(x_train_poly, y_train)
print('R^2 for train data {:.2f}'.format(polynom.score(x_train_poly,y_train)))
print('R^2 for test data {:.2f}'.format(polynom.score(x_test_poly,y_test)))

# %% [markdown]
# The expected values of R^2:<br>
# For train data ~ 0.98 <br>
# For test data ~ 0.98

# %%
#Predict values and build graphic with predicted and actual values
yhat = polynom.predict(x_test_poly)
plt.title('Prediction for product Frame & body')
plt.xlabel('Index')
plt.ylabel('Total cost')
plt.plot(y_test.index, y_test, label = 'Actual test data')
plt.plot(y_test.index, yhat, label = 'Predicted test data')
plt.legend()

# %% [markdown]
# So, analyzing the  $R^{2}$ score for train and test data and graphic with real test data and predicted test data we can make conclusion that our model is trained very well. You see that actual and predicted data is almost equals

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id11" style="text-decoration: none;"><font color="red">Question #11: Multiple Polynomial Regression. Pipeline</font></a></b><br>
# <li><b style="font-size: 1.2em">Split your data for product <b style="font-weight: bold">Suspension & traction</b> into test and train data. Use 10% test data. Set the parameter <code>shuffle = False</code>. (Use method <code>(train_test_split())</code></b></li>
# <li><b style="font-size: 1.2em">Create a pipeline object that scales the data, performs a polynomial transform and fits a linear regression model. Fit the object using the training data and features Quantity, Client type and Payment. Use the hints below</b></li>
# <li><b style="font-size: 1.2em">Calculate the $R^{2}$ for created pipe model <code>(.score())</code> for train and test data</b></li>
# <li><b style="font-size: 1.2em">Predict data using test set. Build graphic with predicted test data and real test data</b></li>
#
# </div>

# %% [markdown]
# The first element in the tuple contains the name of the models
#
# <code>'scale'</code>
#
# <code>'polynomial'</code>
#
# <code>'model'</code>
#
# The second element in the tuple contains the model constructor
#
# <code>StandardScaler()</code>
#
# <code>PolynomialFeatures(include_bias=False)</code>
#
# <code>LinearRegression()</code>

# %%
#Split data and create a pipeline object
x_data = df.loc[df['Product line'] == 'Suspension & traction',['Quantity','Client type','Payment']]
y_data = df.loc[df['Product line'] == 'Suspension & traction',['Total']]
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.1, shuffle = False)
Input = [('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]
pipe = Pipeline(Input)

# %%
#Make all your data in x_train float (use method .astype()). Fit your pipe model. Calculate the R^2 for train and test data. Make conclusion is there underfitting or overfitting or model is trained very well.
x_train = x_train.astype(float)
pipe.fit(x_train, y_train)
print('R^2 for train data {:.2f}'.format(pipe.score(x_train, y_train)))
print('R^2 for test data {:.2f}'.format(pipe.score(x_test, y_test)))

# %% [markdown]
# The expected values of R^2:<br>
# For train data ~ 0.96 <br>
# For test data ~ 0.95

# %%
#Build graphic with predicted and real values
yhat = pipe.predict(x_test)
plt.title('Prediction for product Suspension & traction')
plt.xlabel('Index')
plt.ylabel('Total cost')
plt.plot(y_test.index, y_test, label = 'Actual test data')
plt.plot(y_test.index, yhat, label = 'Predicted test data')
plt.legend()

# %% [markdown]
# Analyzing the  $R^{2}$ score for train and test data and graphic with real test data and predicted test data we can make conclusion that our model is trained very well.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold"><a name="id12" style="text-decoration: none;"><font color="red">Question #12: Ridge Regression</font></a></b><br>
# <li><b style="font-size: 1.2em">Split your data for product <b style="font-weight: bold">Breaking system</b> into test and train data. Use 10% test data. Set the parameter <code>shuffle = False</code>. (Use method <code>(train_test_split())</code></b></li>
# <li><b style="font-size: 1.2em">Create Ridge Regression object with alpha parameter 10 and fit it using train data and feature Quantity</b></li>
# <li><b style="font-size: 1.2em">Calculate the $R^{2}$ for created pipe model <code>(.score())</code> for train and test data</b></li>
# <li><b style="font-size: 1.2em">Predict data using test set. Build graphic with predicted test data and real test data</b></li>
# </div>

# %%
#Split data and create a Ridge Regression object
x_data = df.loc[df['Product line'] == 'Breaking system',['Quantity']]
y_data = df.loc[df['Product line'] == 'Breaking system',['Total']]
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.1, shuffle = False)
RM = Ridge(alpha = 10)

# %%
#Fit the model and calculate R^2 for train and test data. Make conclusion is there underfitting or overfitting or model is trained very well.
RM.fit(x_train,y_train)
print('R^2 for train data {:.2f}'.format(RM.score(x_train, y_train)))
print('R^2 for test data {:.2f}'.format(RM.score(x_test, y_test)))

# %% [markdown]
# The expected values of R^2:<br>
# For train data ~ 0.92 <br>
# For test data ~ 0.47

# %%
#Build graphic with predicted and real values
yhat = RM.predict(x_test)
plt.title('Prediction for product Breaking system')
plt.xlabel('Index')
plt.ylabel('Total cost')
plt.plot(y_test.index, y_test, label = 'Actual test data')
plt.plot(y_test.index, yhat, label = 'Predicted test data')
plt.legend()

# %% [markdown]
# In this case the $R^{2}$ for train and test data very differ. This is overfitting.

# %% [markdown]
# <b style="font-size:1.2em; font-weight:bold">Conclusion</b>

# %% [markdown]
# From models above the best model is Polynomial model with degree=4. This model the best predict Total cost of purchase for product specific type

# %% [markdown]
# ### Thank you for completing this lab!
#
# ## Author
#
# <a href="https://author.skills.network/instructors/victor_dyrenko?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0YF2EN3192-2023-01-01">Victor Dyrenko</a>
#
# <a href="https://author.skills.network/instructors/yaroslav_vyklyuk_2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0YF2EN3192-2023-01-01">Yaroslav Vyklyuk</a>
#
# <a href="https://author.skills.network/instructors/olga_kavun?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0YF2EN3192-2023-01-01">Olga Kavun</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------        | ---------------------------------- |
# | 2023-05-12        | 1       | Victor Dyrenko    | Finished lab                       |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2023. All rights reserved. <h3/>
