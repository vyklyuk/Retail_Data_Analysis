# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Online sales of goods analysis
# ## **Lab. 3. Data Analysis with Python**
#
# Estimated time needed: **50** minutes
#
# <!-- ## Objectives
#
# After completing this lab you will be able to:
#
# *   Explore features or charecteristics to predict turnover(price of car)
#  -->
# <h3>Context</h3>
#
# <p>You will get a transnational dataset, which contains all the transactions occurring between 2010 and 2011 online retail. These information is collected from the countries like US, UK, France etc. <br>The goal of this laboratory work is to Explore features or charecteristics to predict total turnover.</p>
#
#
# <b>Within the Dataset file, following fields are present:</b>
# * Invoice Number: Invoice number. Nominal. A 6-digit integral number uniquely assigned to each transaction. If this code starts with the letter 'c', it indicates a cancellation.
# * Stock Code: Product (item) code. Nominal. A 5-digit integral number uniquely assigned to each distinct product.
# * Description: Product (item) name. Nominal.
# * Quantity: The quantities of each product (item) per transaction. Numeric.
# * Invoice Date: Invoice date and time. Numeric. The day and time when a transaction was generated.
# * Unit Price: Unit price. Numeric. Product price per unit in sterling (£).
# * Unit Price-USD: Unit price. Numeric. Product price per unit in USDT ($).
# * Customer ID: Customer number. Nominal. A 5-digit integral number uniquely assigned to each customer.
# * Country: Country name. Nominal. The name of the country where a customer resides.
# * Turnover-GBP: turnover per line (quantity * unitprice of product) in GBP (sterling).
# * Turnover-USD: turnover per line (quantity * unitprice of product) in USDT.
# * year: year of an invoice from Invoice Date
# * year-month: year and month of an invoice from Invoice Date
#
# <b>Target fields:</b>
# * Total turnover
#
# ### License:
# <a href="https://creativecommons.org/publicdomain/zero/1.0/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX08J0EN2930-2023-01-01">CC0 1.0 Universal (CC0 1.0) Public Domain Dedication</a></li>
# <p>The person who associated a work with this deed has dedicated the work to the public domain by waiving all of his or her rights to the work worldwide under copyright law, including all related and neighboring rights, to the extent allowed by law.
#
# You can copy, modify, distribute and perform the work, even for commercial purposes, all without asking permission.</p>
# <p>

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
#     <li><a href="#part1">Import Data from Module</a></li>
#     <li><a href="#part2">Analyzing Individual Feature Patterns using Visualization</a></li>
#     <li><a href="#part3">Descriptive Statistical Analysis</a></li>
#     <li><a href="#part4">Correlation and Causation</a></li>
#     <li><a href="#part5">ANOVA</a></li>
# </ol>
#
# </div>
#
# <hr>

# %% [markdown]
# <h3>What are the main characteristics that have the most impact on the total turnover?</h3>

# %% [markdown]
# <h2><a name="part1" style="color: black; text-decoration: none;">1. Import Data from Module 2</a></h2>

# %% [markdown]
# <h4>Setup</h4>

# %% [markdown]
# If you run the lab locally using Anaconda, you can load the correct library and versions by uncommenting the following:

# %%
#If you run the lab locally using Anaconda, you can load the correct library and versions by uncommenting the following:
#install specific version of libraries used in lab
#! mamba install pandas==1.3.3
#! mamba install numpy=1.21.2
#! mamba install scipy=1.7.1-y
#! mamba install seaborn=0.9.0-y
# ! pip install seaborn
# ! pip install scikit-learn
# ! pip install dython

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from dython.nominal import associations

# %% [markdown]
# Load the data and store it in dataframe `df`:

# %% [markdown]
# This dataset was hosted on IBM Cloud object. Click <a href="https://cocl.us/DA101EN_object_storage?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork20235326-2021-01-01">HERE</a> for free storage.

# %%
filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0E9TEN/clean_df_3.csv"

# %% [markdown]
# Use the Pandas method <b>read_csv()</b> to load the data from the web address. Set the parameter  "names" equal to the Python list "headers".

# %%
df = pd.read_csv(filename)

# %% [markdown]
# Use the method <b>head()</b> to display the first five rows of the dataframe.

# %%
# To see what the data set looks like, we'll use the head() method.
df.head()

# %% [markdown]
# We do not need columns 'year' and 'year-month', because we can get year or month from column field 'Invoice Date'.
#
# So we delete these two columns from the dataframe.

# %%
df=df.drop(columns = ['year','year-month'])

#check updated df
df.head()

# %% [markdown]
# <h2><a name="part2" style="color: black; text-decoration: none;">2. Analyzing Individual Feature Patterns Using Visualization</a></h2>

# %% [markdown]
# To install Seaborn we use pip, the Python package manager.

# %% [markdown]
# Import visualization packages "Matplotlib" and "Seaborn". Don't forget about "%matplotlib inline" to plot in a Jupyter notebook.

# %%
# Matplotlib and Seaborn imported below
# %matplotlib inline

# %% [markdown]
# <h4>How to choose the right visualization method?</h4>
# <p>When visualizing individual variables, it is important to first understand what type of variable you are dealing with. This will help us find the right visualization method for that variable.</p>

# %%
# list the data types for each column
print(df.dtypes)

# %% [markdown]
# <h4>Convert data types to proper format</h4>

# %%
df[["Customer ID"]] = df[["Customer ID"]].astype("int64")

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question  #1:</b>
#
# <b>Your tasks:</b>
#
# <b>1. Convert data type of "Country" to "category" </b>
#
# <b>2. Convert data type of "Invoice Date" to "datetime64[ns]" </b>
#
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[["Country"]] = df[["Country"]].astype("category")
# df[["Invoice Date"]] = df[["Invoice Date"]].astype('datetime64[ns]')
# ```
#
# </details>

# %%
#check datatypes again
df.dtypes

# %% [markdown]
# For example, we can calculate the correlation between variables  of type "int64" or "float64" using the method "corr":

# %%
df.corr()

# %% [markdown]
# The diagonal elements are always one; we will study correlation more precisely Pearson correlation in-depth at the end of the notebook.

# %% [markdown]
# <p>Find coefficient of correlation for Category fields, as well using <code>associations()</code></p>

# %%
fig, ax = plt.subplots(figsize=(16, 8))
r = associations(df[['Quantity', 'Unit Price', 'Customer ID', 'Unit Price-USD', 'Turnover-GBP', 'Turnover-USD', 'Country']], ax = ax, cmap = "Blues")

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question  #2: </b>
#
# <p>Find the correlation between the following columns: Quantity, Unit-Price-USD and Turnover-USD.</p>
# <p>Hint: Use the following syntax: df[['Quantity',' Unit Price-USD','Turnover-USD']]</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[['Quantity','Unit Price-USD','Turnover-USD']].corr()
# ```
#
# </details>

# %% [markdown]
# <h2>Continuous Numerical Variables:</h2>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an individual variable and the price, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data.</p>

# %% [markdown]
# Let's see several examples of different linear relationships:

# %% [markdown]
# <h3>Positive Linear Relationship</h4>

# %% [markdown]
# Let's find the scatterplot of "Quantity" and "Turnover-USD".

# %%
# Quantity bought prodyct as potensial predictor variable of turnover
sns.regplot(x="Quantity", y="Turnover-USD", data=df)
plt.xlim(-10000,15000)
plt.ylim(-10000,10000)

# %% [markdown]
# <p>As the Quantity goes up, the Turnover goes up: this indicates a positive direct correlation between these two variables. Quantity of products seems like a good predictor of Turnover (but the data points are very scattered and far from the fitted line, showing lots of variability).</p>

# %%
# # Quantity bought prodyct as potensial predictor variable of turnover
# sns.regplot(x="Quantity", y="Turnover-USD", data=df)
# plt.xlim(0,7000)
# plt.ylim(0,2000)

# %% [markdown]
# We can examine the correlation between 'Quantity' and 'Turnover-USD' and see that it's approximately 0.92.

# %%
df[["Quantity", "Turnover-USD"]].corr()

# %% [markdown]
#  <div class="alert alert-danger alertdanger" style="margin-top: 20px">
#
# <b style="font-size: 2em; font-weight: bold;"> For your practice: <br> Question  3 a): </b>
#
# <p>Find the correlation  between x="Turnover-GBP" and y="Turnover-USD".</p>
# <p>Hint: Use the following syntax: df[["Turnover-GBP","Turnover-USD"]].  </p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #The correlation is 1, the non-diagonal elements of the table.
#
# df[["Turnover-GBP","Turnover-USD"]].corr()
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question  3 b):</b>
#
# <p>Given the correlation results between "Turnover-GBP" and "Turnover-USD", do you expect a linear relationship?</p>
# <p>Verify your results using the function "regplot()".</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #There is a positive correlation between the variable 'Turnover-GBP' and 'Turnover-USD'. We can see this using "regplot" to demonstrate this.
#
# #Code:
# sns.regplot(x="Turnover-GBP", y="Turnover-USD", data=df)
#
# ```
#
# </details>

# %% [markdown]
# <h3>Weak Linear Relationship</h3>

# %% [markdown]
# Let's see if "Unit Price-USD" is a predictor variable of "Turnover-USD".

# %%
sns.regplot(x="Unit Price-USD", y="Turnover-USD", data=df)
plt.xlim(-1000,6000)
plt.ylim(-15000,15000)

# %% [markdown]
# <p>Price for unit of product does not seem like a good predictor of the Turnover since the regression line is close to horizontal or negative.</p>

# %% [markdown]
# We can examine the correlation between 'Unit Price-USD' and 'Turnover-USD' and see it's approximately -0.128961.

# %%
df[['Unit Price-USD','Turnover-USD']].corr()

# %% [markdown]
#  <div class="alert alert-danger alertdanger" style="margin-top: 20px">
#
# <b style="font-size: 2em; font-weight: bold;"> Question  4 a): </b>
#
# <p>Find the correlation  between x="Quantity" and y="Unit Price-USD".</p>
# <p>Hint: Use the following syntax: df[["Quantity","Unit Price-USD"]].  </p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #The correlation is -0.001236, the non-diagonal elements of the table.
#
# df[["Quantity","Unit Price-USD"]].corr()
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question  4 b):</b>
#
# <p>Given the correlation results between "Quantity" and "Unit Price-USD", do you expect a linear relationship?</p>
# <p>Verify your results using the function "regplot()".</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #There is a weak correlation between the variable 'Quantity' and 'Unit Price-USD'. We can see this using "regplot" to demonstrate this.
#
# #Code:
# sns.regplot(x="Quantity", y="Unit Price-USD", data=df)
#
# ```
#
# </details>

# %% [markdown]
# <h3>Categorical Variables</h3>
#
# <p>These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.</p>

# %% [markdown]
# Let's look at the relationship between "Country" and "Turnover-USD".

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x="Country", y="Turnover-USD", data=df)
plt.xticks(rotation=90);
plt.ylim(-200,400)

# %% [markdown]
# <h2><a name="part3" style="color: black; text-decoration: none;">3. Descriptive Statistical Analysis</a></h2>

# %% [markdown]
# <p>Let's first take a look at the variables by utilizing a description method.</p>
#
# <p>The <b>describe</b> function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.</p>
#
# This will show:
#
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %% [markdown]
# We can apply the method "describe" as follows:

# %%
df.describe()

# %% [markdown]
# The default setting of "describe" skips variables of type object. We can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include=['object'])

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question  5:</b>
#
# <p>Apply the method "describe" on the variables of type 'category' as below.</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #Code:
# df.describe(include=['category'])
#
# ```
#
# </details>

# %% [markdown]
# <h3>Value Counts</h3>

# %% [markdown]
# <p>Value counts is a good way of understanding how many units of each characteristic/variable we have. We can apply the "value_counts" method on the column "Description". Don’t forget the method "value_counts" only works on pandas series, not pandas dataframes. As a result, we only include one bracket <code>df['Description']</code>, not two brackets <code>df[['Description']]</code>.</p>

# %%
df['Description'].value_counts()

# %% [markdown]
# <h5>We can convert the series to a dataframe as follows:</h5>

# %%
df['Description'].value_counts().to_frame()

# %% [markdown]
# Let's repeat the above steps but save the results to the dataframe "description_counts" and rename the column  'Description' to 'Value Counts'.

# %%
description_counts = df['Description'].value_counts().to_frame()
description_counts.rename(columns={'Description': 'Value Counts'}, inplace=True)
description_counts

# %% [markdown]
# Now let's rename the index to 'Product Description':

# %%
description_counts.index.name = 'Product Description'
description_counts

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question 6:</b>
#
# <p>Repeat the above process for the variable 'Country'.</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #Code:
# country_counts = df['Country'].value_counts().to_frame()
# country_counts.rename(columns={'Country': 'Value Counts'}, inplace=True)
# country_counts.index.name = 'Country'
# country_counts.head(10)
#
# ```
#
# </details>

# %% [markdown]
# <h2><a name="part4" style="color: black; text-decoration: none;">4. Correlation and Causation</a></h2>

# %% [markdown]
# <p><b>Correlation</b>: a measure of the extent of interdependence between variables.</p>
#
# <p><b>Causation</b>: the relationship between cause and effect between two variables.</p>
#
# <p>It is important to know the difference between these two. Correlation does not imply causation. Determining correlation is much simpler  the determining causation as causation may require independent experimentation.</p>

# %% [markdown]
# <p><b>Pearson Correlation</b></p>
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li><b>1</b>: Perfect positive linear correlation.</li>
#     <li><b>0</b>: No linear correlation, the two variables most likely do not affect each other.</li>
#     <li><b>-1</b>: Perfect negative linear correlation.</li>
# </ul>

# %% [markdown]
# <p>Pearson Correlation is the default method of the function "corr". Like before, we can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>

# %%
df.corr()

# %% [markdown]
# Sometimes we would like to know the significant of the correlation estimate.

# %% [markdown]
# <b>P-value</b>
#
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
#
# <ul>
#     <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %% [markdown]
# We can obtain this information using  "stats" module in the "scipy"  library.

# %% [markdown]
# <h3>Unit Price vs. Turnover</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Unit Price-USD' and 'Turnover-USD'.

# %%
pearson_coef, p_value = stats.pearsonr(df['Unit Price-USD'], df['Turnover-USD'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between Unit Price and Turnover is statistically significant, although the linear relationship isn't strong (~ -0.12896).</p>

# %% [markdown]
# <h3>Quantity vs. Turnover</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Quantity' and 'Turnover-USD'.

# %%
pearson_coef, p_value = stats.pearsonr(df['Quantity'], df['Turnover-USD'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)

# %% [markdown]
# <h4>Conclusion:</h4>
#
# <p>Since the p-value is $<$ 0.001, the correlation between Quantity and Turnover is statistically significant, and the linear relationship is quite strong (~0.915, close to 1).</p>

# %% [markdown]
# <h3>Customer ID vs. Turnover</h3>
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Customer ID' and 'Turnover-USD'.

# %%
pearson_coef, p_value = stats.pearsonr(df['Customer ID'], df['Turnover-USD'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $>$ 0.1, there is no evidence that the correlation between Customer ID and Turnover is significant, and the linear relationship is moderately strong (~-0.0024).</p>

# %% [markdown]
# <h2><a name="part5" style="color: black; text-decoration: none;">5. ANOVA</a></h2>

# %% [markdown]
# <h3>ANOVA: Analysis of Variance</h3>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant our calculated score value is.</p>
#
# <p>If our price variable is strongly correlated with the variable we are analyzing, we expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %% [markdown]
# <h3>Country</h3>

# %% [markdown]
# <p>Since ANOVA analyzes the difference between different groups of the same variable, the groupby function will come in handy. Because the ANOVA algorithm averages the data automatically, we do not need to take the average before hand.</p>
#
# <p>To see if different countries of 'Country' impact  'Turnover-USD', we group the data.</p>

# %%
grouped=df.groupby(['Country'])

# %%
df['Country'].unique()

# %% [markdown]
# <p>As you remember we have 37 unique values in column 'Country'</p>

# %%
df.groupby(['Country'])['Turnover-USD'].sum().head(3)

# %% [markdown]
# <p>Let's work with three the most popular countries by Turnover</p>
# <p>Australia    170315.0788<br>
# Austria       12591.3568<br>
# Bahrain         680.0160</p>

# %% [markdown]
# We can obtain the values of the method group using the method "get_group".

# %%
grouped.get_group('Australia')['Turnover-USD']

# %% [markdown]
# We can use the function 'f_oneway' in the module 'stats' to obtain the <b>F-test score</b> and <b>P-value</b>.

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped.get_group('Australia')['Turnover-USD'], grouped.get_group('Austria')['Turnover-USD'], grouped.get_group('Bahrain')['Turnover-USD'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)

# %% [markdown]
# This is a great result with a large F-test score showing a strong correlation and a P-value is very small implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?
#
# Let's examine them separately.

# %% [markdown]
# <h4>Australia and Austria</h4>

# %%
f_val, p_val = stats.f_oneway(grouped.get_group('Australia')['Turnover-USD'], grouped.get_group('Austria')['Turnover-USD']) 
 
print( "ANOVA results: F=", f_val, ", P =", p_val )

# %% [markdown]
# Let's examine the other groups.

# %% [markdown]
# <h4>Australia and Bahrain</h4>

# %%
f_val, p_val = stats.f_oneway(grouped.get_group('Australia')['Turnover-USD'], grouped.get_group('Bahrain')['Turnover-USD'])
   
print( "ANOVA results: F=", f_val, ", P =", p_val)

# %% [markdown]
# <h4>Austria and Bahrain</h4>

# %%
f_val, p_val = stats.f_oneway(grouped.get_group('Austria')['Turnover-USD'], grouped.get_group('Bahrain')['Turnover-USD'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)

# %% [markdown]
# <h3>Conclusion: Important Variables</h3>

# %% [markdown]
# <p>We now have a better idea of what our data looks like and which variables are important to take into account when predicting the total turnover. We have narrowed it down to the following variables:</p>
#
# Continuous numerical variables:
#
# <ul>
#     <li>Quantity</li>
# </ul>
#
#
# <p>As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.</p>

# %% [markdown]
# ### Thank you for completing this lab!
#
# ## Author
#
# <a href="https://author.skills.network/instructors/veronika_lanchuv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0E9TEN2935-2023-01-01">Veronika Lanchuv</a>
#
# ### Other Contributors
#
# <a href="https://author.skills.network/instructors/yaroslav_vyklyuk_2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0E9TEN2935-2023-01-01">Yaroslav Vyklyuk</a>
#
# <a href="https://author.skills.network/instructors/olga_kavun?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0E9TEN2935-2023-01-01">Olga Kavun</a>
#
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2022-04-20        | 2.0     | Veronika   | lab is done                        |
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2023. All rights reserved. <h3/>
