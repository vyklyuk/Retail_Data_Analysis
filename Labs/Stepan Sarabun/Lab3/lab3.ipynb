# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # __Customer Personality Analysis__
#
# # Lab. 3. Data Analysis with Python
#
# Estimated time needed: **30** minutes
#
# # About dataset
# <details><summary>Click here for the details about the dataset</summary>
#
# <b>Attributes</b>
#
# <b>People</b>
#
# * ID: Customer's unique identifier
# * Year_Birth: Customer's birth year
# * Education: Customer's education level
# * Marital_Status: Customer's marital status
# * Income: Customer's yearly household income
# * Kidhome: Number of children in customer's household
# * Teenhome: Number of teenagers in customer's household
# * Dt_Customer: Date of customer's enrollment with the company
# * Recency: Number of days since customer's last purchase
# * Complain: 1 if the customer complained in the last 2 years, 0 otherwise
#
# <b>Products</b>
#
# * MntWines: Amount spent on wine in last 2 years
# * MntFruits: Amount spent on fruits in last 2 years
# * MntMeatProducts: Amount spent on meat in last 2 years
# * MntFishProducts: Amount spent on fish in last 2 years
# * MntSweetProducts: Amount spent on sweets in last 2 years
# * MntGoldProds: Amount spent on gold in last 2 years
#
# <b>Promotion</b>
#
# * NumDealsPurchases: Number of purchases made with a discount
# * AcceptedCmp1: 1 if customer accepted the offer in the 1st campaign, 0 otherwise
# * AcceptedCmp2: 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
# * AcceptedCmp3: 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
# * AcceptedCmp4: 1 if customer accepted the offer in the 4th campaign, 0 otherwise
# * AcceptedCmp5: 1 if customer accepted the offer in the 5th campaign, 0 otherwise
# * Response: 1 if customer accepted the offer in the last campaign, 0 otherwise
#
# <b>Place</b>
#
# * NumWebPurchases: Number of purchases made through the company’s website
# * NumCatalogPurchases: Number of purchases made using a catalogue
# * NumStorePurchases: Number of purchases made directly in stores
# * NumWebVisitsMonth: Number of visits to company’s website in the last month
#
# <b>Target:</b> Influence of customer personality on the amount of wine purchased.
# </details>
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Explore features or charecteristics to predict how much customer will spent on wine

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
#     <li><a href="#id1">Import Data from Module</a></li>
#     <li><a href="#id2">Analyzing Individual Feature Patterns using Visualization</a></li>
#     <li><a href="#id3">Descriptive Statistical Analysis</a></li>
#     <li><a href="#id4">Correlation and Causation</a></li>
#     <li><a href="#id5">ANOVA</a></li>
# </ol>
#
# </div>
#
# <hr>

# %% [markdown]
# <h1 id="data_acquisition">Data Acquisition</h1>
# <details><summary>Click here for the details about the format, source and license of the dataset</summary>
# <br>
# <p>
# There are various formats for a dataset: .csv, .json, .xlsx  etc. The dataset can be stored in different places, on your local machine or sometimes online.<br>
#
# In this section, you will learn how to load a dataset into our Jupyter Notebook.<br>
#
# In our case, the Customer Personality Dataset is an online source, and it is in a CSV (comma separated value) format. Let's use this dataset as an example to practice data reading.
#
# <ul>
#     <li>Data source: <a href="https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0HQ3EN2917-2023-01-01">https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis</a></li>
#     <li>Data type: csv</li>
#     <li>License: <a href="https://creativecommons.org/publicdomain/zero/1.0/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0HQ3EN2917-2023-01-01">CC0: Public Domain</a>
# </ul>
#
# The Pandas Library is a useful tool that enables us to read various datasets into a dataframe; our Jupyter notebook platforms have a built-in <b>Pandas Library</b> so that all we need to do is import Pandas without installing.
# </p>
# </details>

# %% [markdown]
# <h3>What are the main characteristics that have the most impact on the amount of wine purchased?</h3>

# %% [markdown]
# <b style="font-size: 25px; font-weight: bold; text-decoration: none;"><a name="id1"><font color="black">1. Import Data from Module 2</font></a></b>

# %% [markdown]
# <h4>Setup</h4>

# %%
import pandas as pd
import numpy as np

# %%
filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0HQ3EN/clean_df.csv"

# %%
df = pd.read_csv(filename, index_col=0)

# %% [markdown]
# We will also set options to display only 2 decimals

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# <b style="font-size: 25px; font-weight: bold; text-decoration: none;"><a name="id2"><font color="black">2. Analyzing Individual Feature Patterns Using Visualization</font></a></b>

# %% [markdown]
# Import visualization packages "Matplotlib" and "Seaborn". Don't forget about "%matplotlib inline" to plot in a Jupyter notebook.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h4>How to choose the right visualization method?</h4>
# <p>When visualizing individual variables, it is important to first understand what type of variable you are dealing with. This will help us find the right visualization method for that variable.</p>

# %%
# list the data types for each column
print(df.dtypes)

# %% [markdown]
# For later analysis we need to convert our object type to categoric. We can do it using <code>astype()</code>

# %%
object_columns = df.columns[df.dtypes == 'object']
df[object_columns] = df[object_columns].astype('category')

# %%
df.dtypes

# %% [markdown]
# As we can see data types are appropriate.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;">Question  #1:</b>
#
# <b>What is the data type of the column "Income"? </b>
#
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df['Income'].dtypes
# ```
#
# </details>

# %% [markdown]
# For example, we can calculate the correlation between variables  of type "int64" or "float64" using the method "corr":

# %%
df.corr()

# %% [markdown]
# The diagonal elements are always one; we will study correlation more precisely Pearson correlation in-depth at the end of the notebook.

# %% [markdown]
# We can see, that "Z_CostContact" and "Z_Revenue" show NaN. Let's examine why. As we remember from previous lab there was only one column with missing values - "Income". So what is wrong here? Let's look how many unique values are there.

# %%
print(df['Z_CostContact'].unique())
print(df['Z_Revenue'].unique())

# %% [markdown]
# As we see, each column has only one unique value which means all values are the same. In this case we have to destroy those columns as they will be of no use in any analysis. We can do it using <code>drop()</code>

# %%
df.drop(labels=['Z_CostContact', 'Z_Revenue'], axis=1, inplace=True)

# %%
df.columns

# %% [markdown]
# We can see that there are no such columns anymore.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question  #2: </b>
#
# <p>Find the correlation between the following columns: Year_Birth, Income, Kidhome, and MntWines.</p>
# <p>Hint: if you would like to select those columns, use the following syntax: df[['Year_Birth', 'Income', 'Kidhome', 'MntWines']]</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# ```
#
# </details>

# %% [markdown]
# <h2>Continuous Numerical Variables:</h2>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an individual variable and the price, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data.</p>

# %% [markdown]
# Let's see several examples of different linear relationships:

# %%
# Income as potential predictor variable of money spent
sns.regplot(x="Income", y="MntWines", data=df)
plt.ylim(0, 2000)

# %% [markdown]
# As we can see there are some values that are very unlike most of datapoints. They are called outliers. Let's how many of them are there.

# %%
len(df[df['Income'] > 100000])

# %% [markdown]
# Let's see how much is it in percentage

# %%
(len(df[df['Income'] > 100000]) / len(df)) * 100

# %% [markdown]
# As we can see it is approximately ~0.6% which is very insignificant. Therefore we will get rid of those rows.

# %%
df = df[df['Income'] <= 100000]
df[df['Income'] > 100000].shape

# %% [markdown]
# We can use <code>df.shape</code> to get dimensionality of the dataframe. Now we can see that there are 29 columns, but 0 rows where income is higher than 100000. Let's see what the plot looks like now.

# %%
sns.regplot(x="Income", y="MntWines", data=df)
plt.ylim(0, 2000)

# %% [markdown]
# <p>As the income goes up, the money spent goes up: this indicates a positive direct correlation between these two variables. Income seems like a good predictor of money spent since the regression line is close to perfectly diagonal.</p>

# %% [markdown]
# We can examine the correlation between 'Income' and 'MntWines' and see that it's approximately 0.73.

# %%
df[["Income", "MntWines"]].corr()

# %% [markdown]
# <h3>Weak Linear Relationship</h3>

# %% [markdown]
# Let's see if age is a predictor variable of money spent. Let's find the scatterplot of "Year_Birth" and "MntWines".

# %%
sns.regplot(x="Year_Birth", y="MntWines", data=df)

# %% [markdown]
# At this plot we also can see outliers. Let's think. How old should a person be to be able to buy wine in 1900? Right, that is probably a mistake. To correct it we will set the minimum "Year_Birth" to 1940.

# %%
df = df[df['Year_Birth'] >= 1940]

# %% [markdown]
# Let's verify that it worked correctly.

# %%
df[df['Year_Birth'] < 1940].shape

# %% [markdown]
# Let's see what the plot looks like now.

# %%
sns.regplot(x="Year_Birth", y="MntWines", data=df)

# %% [markdown]
# <p>Age does not seem like a good predictor of the money spent at all since the regression line is close to horizontal. Therefore, it's not a reliable variable.</p>

# %% [markdown]
# We can examine the correlation between 'Year_Birth' and 'MntWines' and see it's approximately -0.165.

# %%
df[['Year_Birth', 'MntWines']].corr()

# %% [markdown]
#  <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;"> Question  3 a): </b>
#
# <p>Find the correlation  between x="MntMeatProducts" and y="MntWines".</p>
# <p>Hint: if you would like to select those columns, use the following syntax: df[["MntMeatProducts","MntWines"]].  </p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #The correlation is 0.5627, the non-diagonal elements of the table.
#
# df[["MntMeatProducts","MntWines"]].corr()
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b style="font-size: 2em; font-weight: bold;">Question  3 b):</b>
#
# <p>Given the correlation results between "MntWines" and "MntMeatProducts", do you expect a linear relationship?</p>
# <p>Verify your results using the function "regplot()".</p>
# </div>

# %%
# Write your code below and press Shift+Enter to execute

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #There is an average correlation between the variable 'MntMeatProducts' and 'MntWines' as such regression will not work the best. We can see this using "regplot" to demonstrate this.
#
# #Code:
# sns.regplot(x="MntMeatProducts", y="MntWines", data=df)
#
# ```
#
# </details>

# %% [markdown]
# <h3>Categorical Variables</h3>
#
# <p>These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "category", "object" or "int64". A good way to visualize categorical variables is by using boxplots.</p>

# %% [markdown]
#  Let's look at the relationship between "Marital_Status" and "MntWines".

# %%
sns.boxplot(x="Marital_Status", y="MntWines", data=df)

# %% [markdown]
# <p>We see that the distributions of money spent between the education levels have a significant overlap, so education would not be a good predictor of money spent. Let's examine "Education" and "MntWines":</p>

# %%
sns.boxplot(x="Education", y="MntWines", data=df)

# %% [markdown]
# <p>Here we see that the distribution of money spent between Education levels, front and rear, are distinct enough to take education as a potential good predictor of money spent.</p>

# %% [markdown]
# Let's look at the relationship between "Average Income" and "MntWines". To do that we will binn our column into four labels: low, less than average, more than average and high average income.

# %%
group_names = ['Low', 'Less average', 'More average', 'High']
bins = np.linspace(min(df["Average Income"]), max(df["Average Income"]), 5)
df['Average Income binned'] = pd.cut(df['Average Income'], bins, labels=group_names, include_lowest=True)

# %% [markdown]
# Let's plot it.

# %%
sns.boxplot(x="Average Income binned", y="MntWines", data=df)

# %% [markdown]
# Now we can clearly see that the higher average income customer has the more wine he buys.

# %% [markdown]
# We can find correlation between categorical variables using "associations". We can install required library using the following command:

# %%
pip install dython

# %%
from dython.nominal import associations

# %% [markdown]
# Firstly we need to convert our data so it is displayed as numbers. For example 'PhD': 0, 'Master': 1 etc. We can use <code>sklearn.preprocessing.OrdinalEncoder</code> to do it.

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
df_copy = df.copy()

# %% [markdown]
# We also created a copy of our dataframe to not affect the original data. Next we will get the columns which will be transformed.

# %%
category_columns = df_copy.columns[df_copy.dtypes == 'category']
category_columns

# %% [markdown]
# Now we will use <code>fit_transform()</code> to transform data.

# %%
df_copy[category_columns] = encoder.fit_transform(df_copy[category_columns])
df_copy[category_columns]

# %% [markdown]
# Finally we will use <code>associations()</code> to get correlations.

# %%
associations(df_copy[category_columns], cmap='Blues')

# %% [markdown]
# <b style="font-size: 25px; font-weight: bold; text-decoration: none;"><a name="id3"><font color="black">3. Descriptive Statistical Analysis</font></a></b>

# %% [markdown]
# <p>Let's first take a look at the variables by utilizing a description method.</p>
#
# <p>The <b>describe</b> function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.</p>
#
# This will show:
#
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %% [markdown]
# We can apply the method "describe" as follows:

# %%
df.describe()

# %% [markdown]
# The default setting of "describe" skips variables of type category. We can apply the method "describe" on the variables of type 'category' as follows:

# %%
df.describe(include=['category'])

# %% [markdown]
# <h3>Value Counts</h3>

# %% [markdown]
# <p>Value counts is a good way of understanding how many units of each characteristic/variable we have. We can apply the "value_counts" method on the column "Year_Birth". Don’t forget the method "value_counts" only works on pandas series, not pandas dataframes. As a result, we only include one bracket <code>df['Year_Birth']</code>, not two brackets <code>df[['Year_Birth']]</code>.</p>

# %%
df['Year_Birth'].value_counts()

# %% [markdown]
# We can convert the series to a dataframe as follows:

# %%
df['Year_Birth'].value_counts().to_frame()

# %% [markdown]
# <b style="font-size: 25px; font-weight: bold; text-decoration: none;"><a name="id4"><font color="black">4. Correlation and Causation</font></a></b>

# %% [markdown]
# <p><b>Correlation</b>: a measure of the extent of interdependence between variables.</p>
#
# <p><b>Causation</b>: the relationship between cause and effect between two variables.</p>
#
# <p>It is important to know the difference between these two. Correlation does not imply causation. Determining correlation is much simpler  the determining causation as causation may require independent experimentation.</p>

# %% [markdown]
# <p><b>Pearson Correlation</b></p>
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li><b>1</b>: Perfect positive linear correlation.</li>
#     <li><b>0</b>: No linear correlation, the two variables most likely do not affect each other.</li>
#     <li><b>-1</b>: Perfect negative linear correlation.</li>
# </ul>

# %% [markdown]
# <p>Pearson Correlation is the default method of the function "corr". Like before, we can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>

# %%
df.corr()

# %% [markdown]
# Sometimes we would like to know the significant of the correlation estimate.

# %% [markdown]
# <b>P-value</b>
#
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
#
# <ul>
#     <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %% [markdown]
# We can obtain this information using  "stats" module in the "scipy"  library.

# %%
from scipy import stats

# %% [markdown]
# <h3>Fish Products vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'MntFishProducts' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['MntFishProducts'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between amount of fish bought and amount of wine bought is statistically significant, although the linear relationship isn't extremely strong (~0.4).</p>

# %% [markdown]
# <h3>Meat Products vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'MntMeatProducts' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['MntMeatProducts'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between amount of meat bought and amount of wine bought is statistically significant, and the linear relationship is moderately strong (~0.5).</p>

# %% [markdown]
# <h3>Deals with discount vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'NumDealsPurchases' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['NumDealsPurchases'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.05, the correlation between number of purchases made with a discount and amount of wine bought is statistically moderate, and the linear relationship is weak (~0.16).</p>

# %% [markdown]
# <h3>Teenhome vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Teenhome' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['Teenhome'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $>$ 0.1, the correlation between number of teenagers in customers household and amount of wine bought is statistically insignificant, and the linear relationship is extremly weak (~0.005).</p>

# %% [markdown]
# <h3>Complain vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Complain' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['Complain'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.1, the correlation between number of purchases made with a discount and amount of wine bought is statistically weak and the linear relationship is very weak (~-0.04).

# %% [markdown]
# <h3>Recency vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'Recency' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['Recency'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $>$ 0.1, the correlation between amount of number of days since customer's last purchase and amount of wine bought is statistically insignificant, and the linear relationship is extremly weak (~0.016).</p>

# %% [markdown]
# <h3>Web Purchases vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'NumWebPurchases' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['NumWebPurchases'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between number of purchases made through the company’s website and amount of wine bought is statistically significant, although the linear relationship isn't extremely strong (~0.5).</p>

# %% [markdown]
# <h3>Catalog Purchases vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'NumCatalogPurchases' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['NumCatalogPurchases'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between number of purchases made using a catalog and amount of wine bought is statistically significant, and the linear relationship is almost strong (~0.67).</p>

# %% [markdown]
# <h3>Store Purchases vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'NumStorePurchases' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['NumStorePurchases'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between number of purchases made directly in stores and amount of wine bought is statistically significant, and the linear relationship is almost strong (~0.64).</p>

# %% [markdown]
# <h3>Web Visits vs. Wine</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'NumWebVisitsMonth' and 'MntWines'.

# %%
pearson_coef, p_value = stats.pearsonr(df['NumWebVisitsMonth'], df['MntWines'])
print(f"The Pearson Correlation Coefficient is {pearson_coef:.3f} with a P-value of P = {p_value}")

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between number of visits to company’s website in the last month and amount of wine bought is statistically significant, although the linear relationship is weak (~-0.33).</p>

# %% [markdown]
# <b style="font-size: 25px; font-weight: bold; text-decoration: none;"><a name="id5"><font color="black">5. ANOVA</font></a></b>

# %% [markdown]
# <h3>ANOVA: Analysis of Variance</h3>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant our calculated score value is.</p>
#
# <p>If our price variable is strongly correlated with the variable we are analyzing, we expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %% [markdown]
# <h3>Education</h3>

# %% [markdown]
# <p>Since ANOVA analyzes the difference between different groups of the same variable, the groupby function will come in handy. Because the ANOVA algorithm averages the data automatically, we do not need to take the average before hand.</p>
#
# <p>To see if different types of 'Education' impact  'MntWines', we group the data, but before we will use <code>sort_by_education(x)</code> that we created in previous lab.</p>

# %%
def sort_by_education(x):
    d = {'PhD': 1, 'Master': 2, '2n Cycle': 3, 'Graduation': 4, 'Basic': 5}
    return x.map(d)

# %%
df_sorted = df[['Education', 'MntWines']].sort_values(by="Education", key=sort_by_education)
df_sorted.groupby(['Education']).count()

# %% [markdown]
# We can obtain the values of the method group using the method "get_group".

# %%
df_sorted.groupby(['Education']).get_group('PhD')['MntWines']

# %% [markdown]
# We can use the function 'f_oneway' in the module 'stats' to obtain the <b>F-test score</b> and <b>P-value</b>.

# %%
df['Education'].unique()

# %%
grouped_test = df_sorted.groupby(['Education'])

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped_test.get_group('Graduation')['MntWines'], grouped_test.get_group('PhD')['MntWines'], 
                              grouped_test.get_group('Master')['MntWines'], grouped_test.get_group('Basic')['MntWines'], 
                              grouped_test.get_group('2n Cycle')['MntWines'])  
 
print(f"ANOVA results: F= {f_val:.3f} P = {p_val}")

# %% [markdown]
# This is a great result with a large F-test score showing a strong correlation and a P-value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?
#
# Let's examine them separately.

# %%
groups = [g for g in grouped_test.groups]
print(groups)

# %%
for i in range(len(groups)-1):
    for j in range(i+1, len(groups)):
        f_val, p_val = stats.f_oneway(grouped_test.get_group(groups[i])['MntWines'], grouped_test.get_group(groups[j])['MntWines']) 
        print(f"{groups[i]}/{groups[j]}: F= {round(f_val, 2)}, P= {p_val}")

# %% [markdown]
# <h3>Conclusion: Important Variables</h3>

# %% [markdown]
# <p>We now have a better idea of what our data looks like and which variables are important to take into account when predicting the amount of wine bought. We have narrowed it down to the following variables:</p>
#
# Continuous numerical variables:
#
# <ul>
#     <li>MntMeatProducts</li>
#     <li>NumWebPurchases</li>
#     <li>NumCatalogPurchases</li>
#     <li>NumStorePurchases</li>
# </ul>
#
# Categorical variables:
#
# <ul>
#     <li>Education</li>
#     <li>Average Income binned</li>
# </ul>
#
# <p>As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.</p>
# <p>From now on we only will target field and fields that impact target field the most</p>

# %%
clean_df = df[['MntWines', 'MntMeatProducts', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'Education', 'Average Income binned']]
clean_df.to_csv('clean_df.csv')

# %% [markdown]
# ### Thank you for completing this lab!

# %% [markdown]
# ## Authors

# %% [markdown]
# Developer: [Yaroslav Vyklyuk, prof., PhD., DrSc](http://vyklyuk.bukuniver.edu.ua/en/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0HQ3EN2917-2023-01-01)

# %% [markdown]
# Retail Consultant: [Olha Vdovichena, ass. prof, PhD](https://scholar.google.ru/citations?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0HQ3EN2917-2023-01-01&user=3vIQ33YAAAAJ&hl=uk)

# %% [markdown]
# Developer: [Stepan Sarabun](https://author.skills.network/instructors/stepan_sarabun_2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0HQ3EN2917-2023-01-01)

# %% [markdown]
# Copyright &copy; 2023 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkGuidedProjectsIBMSkillsNetworkGPXX0HQ3EN2917-2023-01-01).
